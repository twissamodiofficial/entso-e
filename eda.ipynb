# %%
import pandas as pd
import matplotlib.pyplot as plt
from feature_engineering import load_and_clean

# %%
df = pd.read_csv('data/raw/load_train.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 245472 entries, 0 to 245471
# Data columns (total 2 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   Unnamed: 0   245472 non-null  object
#  1   Actual Load  245472 non-null  float64
# dtypes: float64(1), object(1)
# memory usage: 3.7+ MB

# %%
df.shape
# Out:
# (245472, 2)

# %%
df['DateTime'] = pd.to_datetime(df['Unnamed: 0'], utc=True)

# %%
df['DateTime'] = df['DateTime'].dt.tz_convert('Europe/Amsterdam')

# %%
df = df.drop(columns=['Unnamed: 0'])

# %%
df.head(10)
# Out:
#    Actual Load                  DateTime
# 0     11267.78 2019-01-01 00:00:00+01:00
# 1     11279.78 2019-01-01 00:15:00+01:00
# 2     11287.25 2019-01-01 00:30:00+01:00
# 3     11304.48 2019-01-01 00:45:00+01:00
# 4     11265.80 2019-01-01 01:00:00+01:00
# 5     11251.71 2019-01-01 01:15:00+01:00
# 6     11184.59 2019-01-01 01:30:00+01:00
# 7     11072.44 2019-01-01 01:45:00+01:00
# 8     11042.94 2019-01-01 02:00:00+01:00
# 9     11001.69 2019-01-01 02:15:00+01:00

# %%
df.set_index('DateTime', inplace=True)

# %%
load = df.resample('h').mean()

# %%
load.shape
# Out:
# (61368, 1)

# %%
load.head()
# Out:
#                            Actual Load
# DateTime
# 2019-01-01 00:00:00+01:00   11284.8225
# 2019-01-01 01:00:00+01:00   11193.6350
# 2019-01-01 02:00:00+01:00   10933.3600
# 2019-01-01 03:00:00+01:00   10666.5800
# 2019-01-01 04:00:00+01:00   10413.3575

# %%
load.isna().sum()
# Out:
# Actual Load    0
# dtype: int64

# %%
fig, ax = plt.subplots(figsize=(12, 6))
load.groupby([load.index.hour, load.index.year]).mean().unstack().plot(ax=ax, alpha=0.6)
load.groupby(load.index.hour).mean().plot(ax=ax, color='black', linewidth=2)
plt.show()

# %% [markdown]
# daily seasonality
#
# trough ~4am, rises to a morning peak ~8-9am, dips slightly midday, climbs to the daily peak ~6pm, then declines steadily overnight back to the trough.

# %%
fig, ax = plt.subplots(figsize=(12, 6))
load.groupby([load.index.month, load.index.year]).mean().unstack().plot(ax=ax, alpha=0.6)
load.groupby(load.index.month).mean().plot(ax=ax, color='black', linewidth=2)
plt.show()

# %% [markdown]
# annual seasonality

# %%
fig, ax = plt.subplots(figsize=(12, 6))
load.groupby([load.index.day_of_week, load.index.year]).mean().unstack().plot(ax=ax, alpha=0.6)
load.groupby(load.index.day_of_week).mean().plot(ax=ax, color='black', linewidth=2)
plt.show()

# %% [markdown]
# weekly seasonality

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

# %%
fig, ax = plt.subplots(2, 1, figsize=(12, 10))
plot_acf(load, lags=48, ax=ax[0], alpha=0.05)
plot_pacf(load, lags=48, ax=ax[1], alpha=0.05)
plt.show()

# %%
from statsmodels.tsa.seasonal import STL
plt.figure(figsize=(12, 6))
stl = STL(load, seasonal=13, period=24)
result = stl.fit()
result.plot()
plt.show()

# %%
residuals = result.resid
fig, ax = plt.subplots(2, 1, figsize=(12, 10))
plot_acf(residuals, lags=200, ax=ax[0], alpha=0.05)
plot_pacf(residuals, lags=200, ax=ax[1], alpha=0.05)
plt.show()

# %% [markdown]
# 1,2,3, 24 lag and datetime features like hour, day of the week, month
#
# but 1,2,3 lag would not be present in direct forecasting

# %%
from sklearn.pipeline import make_union, make_pipeline
from sktime.transformations.summarize import WindowSummarizer
from feature_engine.datetime import DatetimeFeatures

# %%
ws = WindowSummarizer(target_cols=['Actual Load'], lag_feature={"mean": [[24, 24]], "lag": [24]}, n_jobs=1)

# %%
df_ws = ws.fit_transform(load)

# %%
dtf = DatetimeFeatures(variables="index",features_to_extract=['hour', 'day_of_week', 'month','weekend'])

# %%
df_dtf = dtf.fit_transform(df_ws)

# %%
df_dtf
# Out:
#                            Actual Load_mean_24_24  Actual Load_lag_24  hour  \
# DateTime
# 2019-01-01 00:00:00+01:00                     NaN                 NaN     0
# 2019-01-01 01:00:00+01:00                     NaN                 NaN     1
# 2019-01-01 02:00:00+01:00                     NaN                 NaN     2
# 2019-01-01 03:00:00+01:00                     NaN                 NaN     3
# 2019-01-01 04:00:00+01:00                     NaN                 NaN     4
# ...                                           ...                 ...   ...
# 2025-12-31 19:00:00+01:00            14932.784427         16744.98750    19
# 2025-12-31 20:00:00+01:00            14938.537833         16242.53900    20
# 2025-12-31 21:00:00+01:00            14942.283969         15442.39075    21
# 2025-12-31 22:00:00+01:00            14948.517479         14600.84325    22
# 2025-12-31 23:00:00+01:00            14952.824833         13887.71000    23
#
#                            day_of_week  month  weekend
# DateTime
# 2019-01-01 00:00:00+01:00            1      1        0
# 2019-01-01 01:00:00+01:00            1      1        0
# 2019-01-01 02:00:00+01:00            1      1        0
# 2019-01-01 03:00:00+01:00            1      1        0
# 2019-01-01 04:00:00+01:00            1      1        0
# ...                                ...    ...      ...
# 2025-12-31 19:00:00+01:00            2     12        0
# 2025-12-31 20:00:00+01:00            2     12        0
# 2025-12-31 21:00:00+01:00            2     12        0
# 2025-12-31 22:00:00+01:00            2     12        0
# 2025-12-31 23:00:00+01:00            2     12        0
#
# [61368 rows x 6 columns]

# %%
updated_load = pd.concat([df_dtf, load], axis=1)

# %%
updated_load.head(24)
# Out:
#                            Actual Load_mean_24_24  Actual Load_lag_24  hour  \
# DateTime
# 2019-01-01 00:00:00+01:00                     NaN                 NaN     0
# 2019-01-01 01:00:00+01:00                     NaN                 NaN     1
# 2019-01-01 02:00:00+01:00                     NaN                 NaN     2
# 2019-01-01 03:00:00+01:00                     NaN                 NaN     3
# 2019-01-01 04:00:00+01:00                     NaN                 NaN     4
# 2019-01-01 05:00:00+01:00                     NaN                 NaN     5
# 2019-01-01 06:00:00+01:00                     NaN                 NaN     6
# 2019-01-01 07:00:00+01:00                     NaN                 NaN     7
# 2019-01-01 08:00:00+01:00                     NaN                 NaN     8
# 2019-01-01 09:00:00+01:00                     NaN                 NaN     9
# 2019-01-01 10:00:00+01:00                     NaN                 NaN    10
# 2019-01-01 11:00:00+01:00                     NaN                 NaN    11
# 2019-01-01 12:00:00+01:00                     NaN                 NaN    12
# 2019-01-01 13:00:00+01:00                     NaN                 NaN    13
# 2019-01-01 14:00:00+01:00                     NaN                 NaN    14
# 2019-01-01 15:00:00+01:00                     NaN                 NaN    15
# 2019-01-01 16:00:00+01:00                     NaN                 NaN    16
# 2019-01-01 17:00:00+01:00                     NaN                 NaN    17
# 2019-01-01 18:00:00+01:00                     NaN                 NaN    18
# 2019-01-01 19:00:00+01:00                     NaN                 NaN    19
# 2019-01-01 20:00:00+01:00                     NaN                 NaN    20
# 2019-01-01 21:00:00+01:00                     NaN                 NaN    21
# 2019-01-01 22:00:00+01:00                     NaN                 NaN    22
# 2019-01-01 23:00:00+01:00                     NaN                 NaN    23
#
#                            day_of_week  month  weekend  Actual Load
# DateTime
# 2019-01-01 00:00:00+01:00            1      1        0   11284.8225
# 2019-01-01 01:00:00+01:00            1      1        0   11193.6350
# 2019-01-01 02:00:00+01:00            1      1        0   10933.3600
# 2019-01-01 03:00:00+01:00            1      1        0   10666.5800
# 2019-01-01 04:00:00+01:00            1      1        0   10413.3575
# 2019-01-01 05:00:00+01:00            1      1        0   10440.7925
# 2019-01-01 06:00:00+01:00            1      1        0   10669.5625
# 2019-01-01 07:00:00+01:00            1      1        0   10898.5625
# 2019-01-01 08:00:00+01:00            1      1        0   11161.1075
# 2019-01-01 09:00:00+01:00            1      1        0   11463.0550
# 2019-01-01 10:00:00+01:00            1      1        0   11837.1675
# 2019-01-01 11:00:00+01:00            1      1        0   12257.7550
# 2019-01-01 12:00:00+01:00            1      1        0   12492.5600
# 2019-01-01 13:00:00+01:00            1      1        0   12609.5650
# 2019-01-01 14:00:00+01:00            1      1        0   12587.4400
# 2019-01-01 15:00:00+01:00            1      1        0   12708.8875
# 2019-01-01 16:00:00+01:00            1      1        0   13076.5050
# 2019-01-01 17:00:00+01:00            1      1        0   14079.0575
# 2019-01-01 18:00:00+01:00            1      1        0   13950.3575
# 2019-01-01 19:00:00+01:00            1      1        0   13678.0075
# 2019-01-01 20:00:00+01:00            1      1        0   13310.6550
# 2019-01-01 21:00:00+01:00            1      1        0   12761.6675
# 2019-01-01 22:00:00+01:00            1      1        0   12221.9750
# 2019-01-01 23:00:00+01:00            1      1        0   11521.7475

# %%
import holidays
nl_holidays = holidays.Netherlands(years=range(2019, 2027))

# %%
nl_holidays
# Out:
# {datetime.date(2019, 1, 1): "New Year's Day", datetime.date(2019, 4, 19): 'Good Friday', datetime.date(2019, 4, 21): 'Easter Sunday', datetime.date(2019, 4, 22): 'Easter Monday', datetime.date(2019, 4, 27): "King's Day", datetime.date(2019, 5, 30): 'Ascension Day', datetime.date(2019, 6, 9): 'Pentecost', datetime.date(2019, 6, 10): 'Pentecost Monday', datetime.date(2019, 12, 25): 'Christmas Day', datetime.date(2019, 12, 26): 'Second Day of Christmas', datetime.date(2020, 1, 1): "New Year's Day", datetime.date(2020, 4, 10): 'Good Friday', datetime.date(2020, 4, 12): 'Easter Sunday', datetime.date(2020, 4, 13): 'Easter Monday', datetime.date(2020, 4, 27): "King's Day", datetime.date(2020, 5, 5): 'Liberation Day', datetime.date(2020, 5, 21): 'Ascension Day', datetime.date(2020, 5, 31): 'Pentecost', datetime.date(2020, 6, 1): 'Pentecost Monday', datetime.date(2020, 12, 25): 'Christmas Day', datetime.date(2020, 12, 26): 'Second Day of Christmas', datetime.date(2021, 1, 1): "New Year's Day", datetime.date(2021, 4, 2): 'Good Friday', datetime.date(2021, 4, 4): 'Easter Sunday', datetime.date(2021, 4, 5): 'Easter Monday', datetime.date(2021, 4, 27): "King's Day", datetime.date(2021, 5, 13): 'Ascension Day', datetime.date(2021, 5, 23): 'Pentecost', datetime.date(2021, 5, 24): 'Pentecost Monday', datetime.date(2021, 12, 25): 'Christmas Day', datetime.date(2021, 12, 26): 'Second Day of Christmas', datetime.date(2022, 1, 1): "New Year's Day", datetime.date(2022, 4, 15): 'Good Friday', datetime.date(2022, 4, 17): 'Easter Sunday', datetime.date(2022, 4, 18): 'Easter Monday', datetime.date(2022, 4, 27): "King's Day", datetime.date(2022, 5, 26): 'Ascension Day', datetime.date(2022, 6, 5): 'Pentecost', datetime.date(2022, 6, 6): 'Pentecost Monday', datetime.date(2022, 12, 25): 'Christmas Day', datetime.date(2022, 12, 26): 'Second Day of Christmas', datetime.date(2023, 1, 1): "New Year's Day", datetime.date(2023, 4, 7): 'Good Friday', datetime.date(2023, 4, 9): 'Easter Sunday', datetime.date(2023, 4, 10): 'Easter Monday', datetime.date(2023, 4, 27): "King's Day", datetime.date(2023, 5, 18): 'Ascension Day', datetime.date(2023, 5, 28): 'Pentecost', datetime.date(2023, 5, 29): 'Pentecost Monday', datetime.date(2023, 12, 25): 'Christmas Day', datetime.date(2023, 12, 26): 'Second Day of Christmas', datetime.date(2024, 1, 1): "New Year's Day", datetime.date(2024, 3, 29): 'Good Friday', datetime.date(2024, 3, 31): 'Easter Sunday', datetime.date(2024, 4, 1): 'Easter Monday', datetime.date(2024, 4, 27): "King's Day", datetime.date(2024, 5, 9): 'Ascension Day', datetime.date(2024, 5, 19): 'Pentecost', datetime.date(2024, 5, 20): 'Pentecost Monday', datetime.date(2024, 12, 25): 'Christmas Day', datetime.date(2024, 12, 26): 'Second Day of Christmas', datetime.date(2025, 1, 1): "New Year's Day", datetime.date(2025, 4, 18): 'Good Friday', datetime.date(2025, 4, 20): 'Easter Sunday', datetime.date(2025, 4, 21): 'Easter Monday', datetime.date(2025, 4, 26): "King's Day", datetime.date(2025, 5, 5): 'Liberation Day', datetime.date(2025, 5, 29): 'Ascension Day', datetime.date(2025, 6, 8): 'Pentecost', datetime.date(2025, 6, 9): 'Pentecost Monday', datetime.date(2025, 12, 25): 'Christmas Day', datetime.date(2025, 12, 26): 'Second Day of Christmas', datetime.date(2026, 1, 1): "New Year's Day", datetime.date(2026, 4, 3): 'Good Friday', datetime.date(2026, 4, 5): 'Easter Sunday', datetime.date(2026, 4, 6): 'Easter Monday', datetime.date(2026, 4, 27): "King's Day", datetime.date(2026, 5, 14): 'Ascension Day', datetime.date(2026, 5, 24): 'Pentecost', datetime.date(2026, 5, 25): 'Pentecost Monday', datetime.date(2026, 12, 25): 'Christmas Day', datetime.date(2026, 12, 26): 'Second Day of Christmas'}

# %%
updated_load['is_holiday'] = [int(d in nl_holidays) for d in updated_load.index.date]

# %%
weekday_only = updated_load[updated_load['weekend'] == 0]

holiday_avg = weekday_only[weekday_only['is_holiday'] == 1]['Actual Load'].mean()
non_holiday_avg = weekday_only[weekday_only['is_holiday'] == 0]['Actual Load'].mean()

print(f"Weekday holiday avg load:     {holiday_avg:.0f}")
print(f"Weekday non-holiday avg load: {non_holiday_avg:.0f}")
print(f"Difference: {non_holiday_avg - holiday_avg:.0f} ({(non_holiday_avg-holiday_avg)/non_holiday_avg*100:.1f}%)")
# Out:
# Weekday holiday avg load:     11361
# Weekday non-holiday avg load: 13012
# Difference: 1651 (12.7%)

# %%
holiday_dates = weekday_only[weekday_only['is_holiday'] == 1].index.date
holiday_names = [nl_holidays.get(d) for d in holiday_dates]

per_holiday = weekday_only[weekday_only['is_holiday']==1].groupby(
    weekday_only[weekday_only['is_holiday']==1].index.date
).agg(load=('Actual Load','mean'))
per_holiday['name'] = [nl_holidays.get(d) for d in per_holiday.index]

per_holiday.groupby('name')['load'].mean().sort_values().to_frame().assign(
    pct_below_normal=lambda x: (non_holiday_avg - x['load'])/non_holiday_avg*100
)
# Out:
#                                  load  pct_below_normal
# name
# King's Day                9991.855130         23.210251
# Pentecost Monday         10462.453780         19.593590
# Ascension Day            10556.698393         18.869298
# Easter Monday            10710.287827         17.688927
# Liberation Day           10877.881354         16.400932
# New Year's Day           12237.294958          5.953519
# Good Friday              12244.719390          5.896461
# Second Day of Christmas  12572.292781          3.378983
# Christmas Day            12620.329438          3.009810

# %%
updated_load['holiday_name'] = [nl_holidays.get(d, 'none') for d in updated_load.index.date]
updated_load['holiday_name'] = updated_load['holiday_name'].astype('category')

# %%
updated_load.head()
# Out:
#                            Actual Load_mean_24_24  Actual Load_lag_24  hour  \
# DateTime
# 2019-01-01 00:00:00+01:00                     NaN                 NaN     0
# 2019-01-01 01:00:00+01:00                     NaN                 NaN     1
# 2019-01-01 02:00:00+01:00                     NaN                 NaN     2
# 2019-01-01 03:00:00+01:00                     NaN                 NaN     3
# 2019-01-01 04:00:00+01:00                     NaN                 NaN     4
#
#                            day_of_week  month  weekend  Actual Load  \
# DateTime
# 2019-01-01 00:00:00+01:00            1      1        0   11284.8225
# 2019-01-01 01:00:00+01:00            1      1        0   11193.6350
# 2019-01-01 02:00:00+01:00            1      1        0   10933.3600
# 2019-01-01 03:00:00+01:00            1      1        0   10666.5800
# 2019-01-01 04:00:00+01:00            1      1        0   10413.3575
#
#                            is_holiday    holiday_name
# DateTime
# 2019-01-01 00:00:00+01:00           1  New Year's Day
# 2019-01-01 01:00:00+01:00           1  New Year's Day
# 2019-01-01 02:00:00+01:00           1  New Year's Day
# 2019-01-01 03:00:00+01:00           1  New Year's Day
# 2019-01-01 04:00:00+01:00           1  New Year's Day

# %%
updated_load = updated_load.dropna()

# %%
updated_load.head()
# Out:
#                            Actual Load_mean_24_24  Actual Load_lag_24  hour  \
# DateTime
# 2019-01-02 23:00:00+01:00            12009.090937          11521.7475    23
# 2019-01-03 00:00:00+01:00            11999.559167          11056.0600     0
# 2019-01-03 01:00:00+01:00            11980.122604          10727.1575     1
# 2019-01-03 02:00:00+01:00            11965.111667          10573.0975     2
# 2019-01-03 03:00:00+01:00            11958.658125          10511.6950     3
#
#                            day_of_week  month  weekend  Actual Load  \
# DateTime
# 2019-01-02 23:00:00+01:00            2      1        0   12557.3975
# 2019-01-03 00:00:00+01:00            3      1        0   11983.2600
# 2019-01-03 01:00:00+01:00            3      1        0   11574.3100
# 2019-01-03 02:00:00+01:00            3      1        0   11283.6175
# 2019-01-03 03:00:00+01:00            3      1        0   11176.0000
#
#                            is_holiday holiday_name
# DateTime
# 2019-01-02 23:00:00+01:00           0         none
# 2019-01-03 00:00:00+01:00           0         none
# 2019-01-03 01:00:00+01:00           0         none
# 2019-01-03 02:00:00+01:00           0         none
# 2019-01-03 03:00:00+01:00           0         none

# %%
updated_load.shape
# Out:
# (61321, 9)

# %%
weather_train = pd.read_csv("data/raw/weather_train.csv", index_col=0, parse_dates=True)

load_train = load_and_clean("data/raw/load_train.csv")

weather_train.index = weather_train.index.tz_localize(
    "Europe/Amsterdam", nonexistent="shift_forward", ambiguous="NaT"
)

# drop rows where localization failed (NaT) or duplicated
weather_train = weather_train[weather_train.index.notna()]
weather_train = weather_train[~weather_train.index.duplicated(keep="first")]

load_train = load_and_clean("data/raw/load_train.csv")

combined = pd.concat([load_train, weather_train], axis=1).dropna()

# %%
combined.head()
# Out:
#                            Actual Load  ...  surface_pressure
# 2019-01-01 00:00:00+01:00   11284.8225  ...            1029.5
# 2019-01-01 01:00:00+01:00   11193.6350  ...            1029.0
# 2019-01-01 02:00:00+01:00   10933.3600  ...            1029.1
# 2019-01-01 03:00:00+01:00   10666.5800  ...            1028.8
# 2019-01-01 04:00:00+01:00   10413.3575  ...            1028.3
#
# [5 rows x 16 columns]

# %%
corr_with_load = combined.corr(numeric_only=True)["Actual Load"].drop("Actual Load").sort_values(key=abs, ascending=False)
print(corr_with_load)
# Out:
# apparent_temperature   -0.257759
# temperature_2m         -0.243890
# dew_point_2m           -0.221009
# cloud_cover             0.175193
# direct_radiation       -0.168269
# wind_gusts_10m          0.143123
# shortwave_radiation    -0.129493
# wind_speed_10m          0.117133
# surface_pressure       -0.108934
# relative_humidity_2m    0.096320
# snow_depth              0.064224
# precipitation           0.062451
# rain                    0.057438
# snowfall                0.044334
# diffuse_radiation      -0.009211
# Name: Actual Load, dtype: float64

# %%
high_load_threshold = combined["Actual Load"].quantile(0.9)
high_load_subset = combined[combined["Actual Load"] >= high_load_threshold]

corr_high_load = high_load_subset.corr(numeric_only=True)["Actual Load"].drop("Actual Load").sort_values(key=abs, ascending=False)
print(corr_high_load)
# Out:
# temperature_2m         -0.245962
# apparent_temperature   -0.236761
# dew_point_2m           -0.233948
# direct_radiation       -0.102975
# shortwave_radiation    -0.087318
# wind_speed_10m         -0.081624
# cloud_cover             0.058861
# snowfall                0.052955
# diffuse_radiation      -0.045738
# wind_gusts_10m         -0.033622
# snow_depth              0.029056
# rain                   -0.015371
# surface_pressure        0.013390
# relative_humidity_2m    0.003312
# precipitation          -0.003225
# Name: Actual Load, dtype: float64
